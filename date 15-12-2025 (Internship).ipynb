# %%
pip install virtualenv
# Out:
# ...
#
# ...

# %%
pip install virtualenv2

# %%
pip install pytest-virtualenv
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install gae-virtualenv
# Out:
# ...
#
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
#   error: subprocess-exited-with-error
#
#   python setup.py egg_info did not run successfully.
#   exit code: 1
#
#   [16 lines of output]
#   Traceback (most recent call last):
#     File "<string>", line 2, in <module>
#       exec(compile('''
#       ~~~~^^^^^^^^^^^^
#       # This is <pip-setuptools-caller> -- a caller that pip uses to run setup.py
#       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#       ...<32 lines>...
#       exec(compile(setup_py_code, filename, "exec"))
#       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#       ''' % ('C:\\Users\\HP\\AppData\\Local\\Temp\\pip-install-9lhp4v3d\\gae-virtualenv_b64316f83dec4102b290cbd9530c0bb0\\setup.py',), "<pip-setuptools-caller>", "exec"))
# ...

# %%
pip install arcpy_virtualenv
# Out:
# ...
#   Using cached arcpy_virtualenv-10.5.tar.gz (942 bytes)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   python setup.py egg_info did not run successfully.
#   exit code: 1
#
#   [1 lines of output]
#   error in arcpy_virtualenv setup command: "values of 'package_data' dict" must be a list of strings (got 'windows_10.5.pth')
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# Encountered error while generating package metadata.
#
# See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
pip install activate-virtualenv
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for activate-virtualenv: filename=activate_virtualenv-0.1.5-py3-none-any.whl size=4690 sha256=78b3a00d87efe5bf066b4c392d984bcfcf6938c52d90cf870dfe2020f7fe025a
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\22\b6\ae\956dedf52c191ff09e7ad7b4939aae6cab268d274b755772ea
# Successfully built activate-virtualenv
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyutilib.virtualenv
# Out:
# ...
#
# ...

# %%
pip install fabric-virtualenv
# Out:
# ...
#
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for fabric-virtualenv: filename=fabric_virtualenv-0.3.0-py3-none-any.whl size=3647 sha256=7356002e53c8eba39f57ff515da41b57e8beefd7db81dbae382113c4d86854ac
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\fb\cb\13\93245a2fff17876fd94f15e0fc363bf50f7c7b27ba06368a3b
# Successfully built fabric-virtualenv
# ...
#
#    ---------------------------------------- 0/4 [invoke]
#    ---------------------------------------- 0/4 [invoke]
#    ---------------------------------------- 0/4 [invoke]
#    ---------------------------------------- 0/4 [invoke]
#    ---------------------------------------- 0/4 [invoke]
#    ---------------------------------------- 0/4 [invoke]
#    ---------------------------------------- 0/4 [invoke]
#    ---------------------------------------- 0/4 [invoke]
#    ---------------------------------------- 0/4 [invoke]
# ...

# %%
pip install custom-virtualenv
# Out:
# ...
#
# ...
#   Using cached packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# ...
# Using cached packaging-25.0-py3-none-any.whl (66 kB)
# ...
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----------------- ---------------------- 0.8/1.8 MB 2.1 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.0/1.8 MB 2.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 1.6/1.8 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 2.1 MB/s eta 0:00:00
# ...
#
#   Attempting uninstall: pip
#
#     Found existing installation: pip 25.1
#
#    ---------------------------------------- 0/6 [pip]
#     Uninstalling pip-25.1:
#    ---------------------------------------- 0/6 [pip]
#       Successfully uninstalled pip-25.1
#    ---------------------------------------- 0/6 [pip]
#    ---------------------------------------- 0/6 [pip]
# ...

# %%
pip install virtualenv-activator
# Out:
# ...
#
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for virtualenv-activator: filename=virtualenv_activator-0.1.2-py3-none-any.whl size=4285 sha256=82a877d79fd31a471aea0e7c8c2dbc75bca60eab239faa0d1cfd5afa67474a69
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\49\62\5a\9a4b2da0bc1efa3ca09adc9fa194811bb7f273944e2249c362
# Successfully built virtualenv-activator
# ...

# %%
import pandas as pd
import numpy as np

# %%
tf=pd.read_csv(r"C:\Users\HP\OneDrive\Documents\Main Internship\Task 1 15-12-2025\subject_grade_dataset.csv")
tf
# Out:
#    AttendancePercentage  InternalMarks  AssignmentScore  QuizScore  LabScore  \
# 0                    92             28               18          9        20
# 1                    85             24               15          7        18
# 2                    60             14                8          4        10
# 3                    78             20               14          6        15
# 4                    50             10                6          3         8
# 5                    88             26               17          8        19
# 6                    72             18               12          6        14
# 7                    95             29               19         10        20
# 8                    65             16               10          5        12
# 9                    80             22               15          7        16
#
#    StudyHours_Subject  ExtraClasses PreviousSubjectGrade  Unnamed: 8  \
# ...

# %%
tf.head()
# Out:
#    AttendancePercentage  InternalMarks  AssignmentScore  QuizScore  LabScore  \
# 0                    92             28               18          9        20
# 1                    85             24               15          7        18
# 2                    60             14                8          4        10
# 3                    78             20               14          6        15
# 4                    50             10                6          3         8
#
#    StudyHours_Subject  ExtraClasses PreviousSubjectGrade  Unnamed: 8  \
# 0                  12             1                    B         NaN
# 1                   9             0                    B         NaN
# 2                   3             0                    C         NaN
# 3                   7             1                    B         NaN
# 4                   2             0                    D         NaN
#
#    Unnamed: 9  Unnamed: 10 SubjectGrade
# 0         NaN          NaN            A
# ...

# %%
tf.describe()
# Out:
#        AttendancePercentage  InternalMarks  AssignmentScore  QuizScore  \
# count              10.00000      10.000000        10.000000  10.000000
# mean               76.50000      20.700000        13.400000   6.500000
# std                14.63823       6.254776         4.325634   2.173067
# min                50.00000      10.000000         6.000000   3.000000
# 25%                66.75000      16.500000        10.500000   5.250000
# 50%                79.00000      21.000000        14.500000   6.500000
# 75%                87.25000      25.500000        16.500000   7.750000
# max                95.00000      29.000000        19.000000  10.000000
#
#         LabScore  StudyHours_Subject  ExtraClasses  Unnamed: 8  Unnamed: 9  \
# count  10.000000            10.00000     10.000000         0.0         0.0
# mean   15.200000             7.50000      0.500000         NaN         NaN
# std     4.211096             3.89444      0.527046         NaN         NaN
# ...

# %%
tf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   AttendancePercentage  10 non-null     int64
#  1   InternalMarks         10 non-null     int64
#  2   AssignmentScore       10 non-null     int64
#  3   QuizScore             10 non-null     int64
#  4   LabScore              10 non-null     int64
#  5   StudyHours_Subject    10 non-null     int64
#  6   ExtraClasses          10 non-null     int64
#  7   PreviousSubjectGrade  10 non-null     object
#  8   Unnamed: 8            0 non-null      float64
#  9   Unnamed: 9            0 non-null      float64
#  10  Unnamed: 10           0 non-null      float64
#  11  SubjectGrade          10 non-null     object
# dtypes: float64(3), int64(7), object(2)
# memory usage: 1.1+ KB
